# %%
import tweepy
from twitter import Timeline

# %%
key = "RJHK5moSffpY04onaW6wwvB1n"
secret = "W1akrMeeIBrNSTShhfln1bzvqcsC3lEqGhzDkpK3aMM9ER0TOK"
bearer_token = "AAAAAAAAAAAAAAAAAAAAADBlVQEAAAAA9jTY7TnNr9XVrOiGheOdEzDVL8A%3DbSnS1ClFF9Vpv0XgmdtUctTfiq6NWGdHlE9HDNq8ws3fzCXG68"

# %%
auth = tweepy.AppAuthHandler(key, secret)
api = tweepy.API(auth)

# %%
mw = Timeline('MarketWatch')
mw.load(2011)
# Out:
# Loading tweets for year: 2011 ......
# ---------------------------------------------------------------------------
# TooManyRequests                           Traceback (most recent call last)
# /var/folders/tv/g_tbbk8n6pj4f83qptc1qf6c0000gn/T/ipykernel_78330/1443069287.py in <module>
#       1 mw = Timeline('MarketWatch')
# ----> 2 mw.load(2011)
#
# ~/Desktop/ai349/proj/src/twitter.py in load(self, year)
#      31         ).items(10000000)
#      32
# ---> 33         for tweet in tweets:
#      34             self.tweets.append(tweet)
#      35
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tweepy/cursor.py in __next__(self)
#      84
#      85     def __next__(self):
# ---> 86         return self.next()
#      87
#      88     def next(self):
#
# ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/tweepy/cursor.py in next(self)
#     284         if self.current_page is None or self.page_index == len(self.current_page) - 1:
# ...

# %%
for tweet in mw.tweets:
    print(tweet.created_at)
    print(tweet.text, end="\n\n")
    tweets.append(tweet)

# %%
len(tweets)
# Out:
# 1000

# %%
for tweet in tweets:
    print(f"ID: {tweet.id}")
    print(tweet.created_at)
    print(tweet.text, end="\n\n")
# Out:
# ID: 20948809685139456
# 2010-12-31 21:06:00+00:00
# Stocks log second straight year of gains; Dow industrials close Friday fractionally higher http://on.mktw.net/fm9Kgk
#
# ID: 20923644356075520
# 2010-12-31 19:26:00+00:00
# Copper ends year at record high; Gold logs 10th year of gains http://on.mktw.net/i5NvjD
#
# ID: 20906028497371136
# 2010-12-31 18:16:00+00:00
# Shares of bookstore chain Borders fall 22% as financial crisis deepens http://on.mktw.net/gE8tmH
#
# ID: 20902002863120384
# 2010-12-31 18:00:00+00:00
# Hulbert: Third year of first presidential terms deliver outsized market gains http://on.mktw.net/ehSRd2
#
# ID: 20896970885300224
# 2010-12-31 17:40:00+00:00
# Crude-oil futures turn higher, charging past $90 level http://on.mktw.net/gf4mrx
#
# ID: 20850160196132864
# 2010-12-31 14:34:00+00:00
# U.S. stocks move slightly lower as 2010's final trading session opens http://on.mktw.net/hqw2yS
#
# ID: 20846638704627713
# 2010-12-31 14:20:00+00:00
# ...
