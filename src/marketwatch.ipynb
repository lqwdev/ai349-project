# %%
import marketwatch as mw

# %%
for item in mw.fetch('aapl'): print(item)
# Out:
# Fetching MarketWatch news for aapl at https://www.marketwatch.com/investing/stock/aapl ...... [done]
# 2021-11-01 16:31:00-05:00
# Apple Inc. stock falls Monday, underperforms market
# https://www.marketwatch.com/story/apple-inc-stock-falls-monday-underperforms-market-01635798715-045039ba4576?mod=mw_quote_news
#
# 2021-11-01 09:55:00-05:00
# This new fund gives an ESG flavor to the tech-heavy Nasdaq-100 — and beats the index
# https://www.marketwatch.com/story/new-fund-gives-an-esg-flavor-to-the-tech-heavy-nasdaq-100-and-beats-the-index-11635774945?mod=mw_quote_news
#
# 2021-11-01 13:02:00-05:00
# Warren Buffett’s Berkshire Hathaway Reports Earnings on Saturday. Here’s What to Look for.
# https://www.marketwatch.com/articles/warren-buffetts-berkshire-hathaway-reports-earnings-on-saturday-heres-what-to-look-for-51635786167?mod=mw_quote_news
#
# 2021-11-01 08:43:21-05:00
# Apple planning iPhone feature that could detect car crashes and automatically dial 911: WSJ
# ...

# %%
for item in mw.fetch('tsla'): print(item)
# Out:
# Fetching MarketWatch news for tsla at https://www.marketwatch.com/investing/stock/tsla ...... [done]
# 2021-11-01 16:32:00-05:00
# Tesla Inc. stock outperforms market on strong trading day
# https://www.marketwatch.com/story/tesla-inc-stock-outperforms-market-on-strong-trading-day-01635798778-a2d9c3c546dc?mod=mw_quote_news
#
# 2021-11-01 16:03:00-05:00
# Cathie Wood’s ARK Innovation Fund Gained 10% in October. Thank Tesla and Coinbase.
# https://www.marketwatch.com/articles/cathie-woods-ark-innovation-fund-gained-10-in-october-thank-tesla-and-coinbase-51635797002?mod=mw_quote_news
#
# 2021-11-01 11:39:00-05:00
# Rivian Is Going Public. Opportunity Is Knocking.
# https://www.marketwatch.com/articles/rivian-ipo-ev-51635781188?mod=mw_quote_news
#
# 2021-11-01 14:05:00-05:00
# Elon Musk dangles $6B to fight world hunger — but only if the U.N. can prove his money would solve the problem
# ...

# %%
for item in mw.fetch('goog'): print(item)
# Out:
# Fetching MarketWatch news for goog at https://www.marketwatch.com/investing/stock/goog ...... [done]
# 2021-11-01 16:31:00-05:00
# Alphabet Inc. Cl A stock underperforms Monday when compared to competitors
# https://www.marketwatch.com/story/alphabet-inc-cl-a-stock-underperforms-monday-when-compared-to-competitors-01635798712-bd8e8b3a6483?mod=mw_quote_news
#
# 2021-10-30 11:08:00-05:00
# Big Tech is still headed for its biggest year ever, but Apple and Amazon could cut into profit
# https://www.marketwatch.com/story/big-tech-is-still-headed-for-its-biggest-year-ever-but-apple-and-amazon-could-cut-into-profit-11635606482?mod=mw_quote_news
#
# 2021-10-29 16:39:00-05:00
# This Small-Cap Tech Stock Can Climb 60%
# https://www.marketwatch.com/articles/buy-sonos-stock-pick-51635539985?mod=mw_quote_news
#
# 2021-10-28 11:19:00-05:00
# Do you really know what’s in your ETF?
# https://www.marketwatch.com/story/do-you-really-know-whats-in-your-etf-11635434406?mod=mw_quote_news
#
# ...
